# %% [markdown]
# Before we get started, a couple of reminders to keep in mind when using iPython notebooks:
#
# - Remember that you can see from the left side of a code cell when it was last run if there is a number within the brackets.
# - When you start a new notebook session, make sure you run all of the cells up to the point where you last left off. Even if the output is still visible from when you ran the cells in your previous session, the kernel starts in a fresh state so you'll need to reload the data, etc. on a new session.
# - The previous point is useful to keep in mind if your answers do not match what is expected in the lesson's quizzes. Try reloading the data and run all of the processing steps one by one in order to make sure that you are working with the same variables and data that are at each quiz stage.
#
#
# ## Load Data from CSVs

# %%
import unicodecsv

## Longer version of code (replaced with shorter, equivalent version below)

# enrollments = []
# f = open('enrollments.csv', 'rb')
# reader = unicodecsv.DictReader(f)
# for row in reader:
#     enrollments.append(row)
# f.close()

with open('enrollments.csv', 'rb') as f:
    reader = unicodecsv.DictReader(f)
    enrollments = list(reader)

# %%
#####################################
#                 1                 #
#####################################

## Read in the data from daily_engagement.csv and project_submissions.csv 
## and store the results in the below variables.
## Then look at the first row of each table.
with open('daily_engagement.csv', 'rb') as engagementFile:
    reader = unicodecsv.DictReader(engagementFile)
    daily_engagement = list(reader)

with open ('project_submissions.csv', 'rb') as psubmissionsFile:
    reader = unicodecsv.DictReader(psubmissionsFile)
    project_submissions = list(reader)

# %% [markdown]
# ## Fixing Data Types

# %%
from datetime import datetime as dt

# Takes a date as a string, and returns a Python datetime object. 
# If there is no date given, returns None
def parse_date(date):
    if date == '':
        return None
    else:
        return dt.strptime(date, '%Y-%m-%d')
    
# Takes a string which is either an empty string or represents an integer,
# and returns an int or None.
def parse_maybe_int(i):
    if i == '':
        return None
    else:
        return int(i)

# Clean up the data types in the enrollments table
for enrollment in enrollments:
    enrollment['cancel_date'] = parse_date(enrollment['cancel_date'])
    enrollment['days_to_cancel'] = parse_maybe_int(enrollment['days_to_cancel'])
    enrollment['is_canceled'] = enrollment['is_canceled'] == 'True'
    enrollment['is_udacity'] = enrollment['is_udacity'] == 'True'
    enrollment['join_date'] = parse_date(enrollment['join_date'])
    
enrollments[0]
# Out:
# {'account_key': '448',
#  'cancel_date': datetime.datetime(2015, 1, 14, 0, 0),
#  'days_to_cancel': 65,
#  'is_canceled': True,
#  'is_udacity': True,
#  'join_date': datetime.datetime(2014, 11, 10, 0, 0),
#  'status': 'canceled'}

# %%
# Clean up the data types in the engagement table
for engagement_record in daily_engagement:
    engagement_record['lessons_completed'] = int(float(engagement_record['lessons_completed']))
    engagement_record['num_courses_visited'] = int(float(engagement_record['num_courses_visited']))
    engagement_record['projects_completed'] = int(float(engagement_record['projects_completed']))
    engagement_record['total_minutes_visited'] = float(engagement_record['total_minutes_visited'])
    engagement_record['utc_date'] = parse_date(engagement_record['utc_date'])
    
daily_engagement[0]
# Out:
# {'acct': '0',
#  'lessons_completed': 0,
#  'num_courses_visited': 1,
#  'projects_completed': 0,
#  'total_minutes_visited': 11.6793745,
#  'utc_date': datetime.datetime(2015, 1, 9, 0, 0)}

# %%
# Clean up the data types in the submissions table
for submission in project_submissions:
    submission['completion_date'] = parse_date(submission['completion_date'])
    submission['creation_date'] = parse_date(submission['creation_date'])

project_submissions[0]
# Out:
# {'account_key': '256',
#  'assigned_rating': 'UNGRADED',
#  'completion_date': datetime.datetime(2015, 1, 16, 0, 0),
#  'creation_date': datetime.datetime(2015, 1, 14, 0, 0),
#  'lesson_key': '3176718735',
#  'processing_state': 'EVALUATED'}

# %% [markdown]
# ## Problems in the Data

# %%
#####################################
#                 3                 #
#####################################

## Rename the "acct" column in the daily_engagement table to "account_key".
for item in daily_engagement:    
    item['account_key'] = item['acct']
    del[item['acct']]
    
print(daily_engagement[0]['account_key'])
# Out:
# 0

# %% [markdown]
# Note when running the above cells that we are actively changing the contents of our data variables. If you try to run these cells multiple times in the same session, an error will occur.
#
# ## Investigating the Data

# %%
#####################################
#                 2                 #
#####################################

## Find the total number of rows and the number of unique students (account keys)
## in each table.
engagement_num_rows=len(daily_engagement)
enrollment_num_rows = len(enrollments)             
submission_num_rows = len(project_submissions)

enrollment_keys= set()
enrollment_num_unique_students = 0 

submission_keys= set()
submission_num_unique_students = 0  # Replace this with your code

engagement_keys= set()
engagement_num_unique_students = 0

for enrollment in enrollments:
    enrollment_keys.add(enrollment['account_key'])

enrollment_num_unique_students= len(enrollment_keys)

for submission in project_submissions:
    submission_keys.add(submission['account_key'])

submission_num_unique_students= len(submission_keys)

for engagement in daily_engagement:
    engagement_keys.add(engagement['account_key'])    

engagement_num_unique_students=len(engagement_keys)
    
print('Total rows daily_engagement: ', engagement_num_rows)    
print('Total accounts in daily_engagement: ',  engagement_num_unique_students)
print('')
print('Total rows enrollments: ', enrollment_num_rows) 
print('Total accounts in enrollments: ', enrollment_num_unique_students)
print('')
print('Total rows submisions: ', submission_num_rows)
print('Total accounts in submisions: ', submission_num_unique_students)
#print('')
#print(daily_engagement)
# Out:
# Total rows daily_engagement:  136240
# Total accounts in daily_engagement:  1237
#
# Total rows enrollments:  1640
# Total accounts in enrollments:  1302
#
# Total rows submisions:  3642
# Total accounts in submisions:  743

# %% [markdown]
# ## Missing Engagement Records

# %%
#####################################
#                 4                 #
#####################################

## Find any one student enrollments where the student is missing from the daily engagement table.
## Output that enrollment.

for item in enrollments:
    userkey= item['account_key']
    if userkey not in engagement_keys:        
        print(item)
        break
# Out:
# {'days_to_cancel': 0, 'is_canceled': True, 'cancel_date': datetime.datetime(2014, 11, 12, 0, 0), 'status': 'canceled', 'account_key': '1219', 'is_udacity': False, 'join_date': datetime.datetime(2014, 11, 12, 0, 0)}

# %% [markdown]
# ## Checking for More Problem Records

# %%
#####################################
#                 5                 #
#####################################

## Find the number of surprising data points (enrollments missing from
## the engagement table) that remain, if any.
for item in enrollments:
    userkey= item['account_key']
    days_cancel= item['days_to_cancel']
    if userkey not in engagement_keys:
             if days_cancel!=None:
                if days_cancel > 0:            
                    print(item)                
             else:  
                print(item)
# Out:
# {'days_to_cancel': 59, 'is_canceled': True, 'cancel_date': datetime.datetime(2015, 3, 10, 0, 0), 'status': 'canceled', 'account_key': '1304', 'is_udacity': True, 'join_date': datetime.datetime(2015, 1, 10, 0, 0)}
# {'days_to_cancel': 99, 'is_canceled': True, 'cancel_date': datetime.datetime(2015, 6, 17, 0, 0), 'status': 'canceled', 'account_key': '1304', 'is_udacity': True, 'join_date': datetime.datetime(2015, 3, 10, 0, 0)}
# {'days_to_cancel': None, 'is_canceled': False, 'cancel_date': None, 'status': 'current', 'account_key': '1101', 'is_udacity': True, 'join_date': datetime.datetime(2015, 2, 25, 0, 0)}

# %% [markdown]
# ## Tracking Down the Remaining Problems

# %%
# Create a set of the account keys for all Udacity test accounts
udacity_test_accounts = set()
for enrollment in enrollments:
    if enrollment['is_udacity']:
        udacity_test_accounts.add(enrollment['account_key'])
len(udacity_test_accounts)
# Out:
# 6

# %%
# Given some data with an account_key field, removes any records corresponding to Udacity test accounts
def remove_udacity_accounts(data):
    non_udacity_data = []
    for data_point in data:
        if data_point['account_key'] not in udacity_test_accounts:
            non_udacity_data.append(data_point)
    return non_udacity_data

# %%
# Remove Udacity test accounts from all three tables
non_udacity_enrollments = remove_udacity_accounts(enrollments)
non_udacity_engagement = remove_udacity_accounts(daily_engagement)
non_udacity_submissions = remove_udacity_accounts(project_submissions)

print (len(non_udacity_enrollments))
print (len(non_udacity_engagement))
print (len(non_udacity_submissions))
# Out:
# 1622
# 135656
# 3634

# %% [markdown]
# ## Refining the Question

# %%
#####################################
#                 6                 #
#####################################

## Create a dictionary named paid_students containing all students who either
## haven't canceled yet or who remained enrolled for more than 7 days. The keys
## should be account keys, and the values should be the date the student enrolled.

paid_students = {}

for item in non_udacity_enrollments:
    if item['days_to_cancel'] == None or item['days_to_cancel'] > 7:
        if item['account_key'] not in paid_students or item['join_date'] > paid_students[item['account_key']]:
            paid_students[item["account_key"]]=item['join_date']

print(len(paid_students))
#print(paid_students)
# Out:
# 995

# %% [markdown]
# ## Getting Data from First Week

# %%
# Takes a student's join date and the date of a specific engagement record,
# and returns True if that engagement record happened within one week
# of the student joining.
def within_one_week(join_date, engagement_date):
    time_delta = engagement_date - join_date
    return time_delta.days < 7 and time_delta.days >= 0

# %%
#####################################
#                 7                 #
#####################################

## Create a list of rows from the engagement table including only rows where
## the student is one of the paid students you just found, and the date is within
## one week of the student's join date.

paid_engagement_in_first_week = []

for item in non_udacity_engagement:
    key = item['account_key']
    if key in paid_students and within_one_week(paid_students[key],item['utc_date']):
        paid_engagement_in_first_week.append(item)

print(len(paid_engagement_in_first_week))
#print(paid_engagement_in_first_week)
# Out:
# 6919

# %% [markdown]
# ## Exploring Student Engagement

# %%
from collections import defaultdict

# Create a dictionary of eng agement grouped by student.
# The keys are account keys, and the values are lists of engagement records.
engagement_by_account = defaultdict(list)
for engagement_record in paid_engagement_in_first_week:
    account_key = engagement_record['account_key']
    engagement_by_account[account_key].append(engagement_record)
    #print(engagement_record)

# %%
# Create a dictionary with the total minutes each student spent in the classroom during the first week.
# The keys are account keys, and the values are numbers (total minutes)
total_minutes_by_account = {}
for account_key, engagement_for_student in engagement_by_account.items():
    total_minutes = 0
    for engagement_record in engagement_for_student:
        total_minutes += engagement_record['total_minutes_visited']
    total_minutes_by_account[account_key] = total_minutes
#print(total_minutes_by_account)

# %%
def getStatistics (listOfItems):
    import numpy as np
    import mathplotlib.pyplot as plt
    # %pylab inline
    
    new_List = list(listOfItems.values())
    print('Mean:', np.mean(new_List))
    print('Standard deviation:', str(np.std(new_List)))
    print('Minimum:', str(np.min(new_List)))
    print('Maximum:', str(np.max(new_List)))
    plt.hist(listOfItems)

# %%
#import numpy as np

# Summarize the data about minutes spent in the classroom
#total_minutes = list(total_minutes_by_account.values())
getStatistics(total_minutes_by_account)
#print('Mean:', np.mean(total_minutes))
#print('Standard deviation:', str(np.std(total_minutes)))
#print('Minimum:', str(np.min(total_minutes)))
#print('Maximum:', str(np.max(total_minutes)))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-9f6977e0edc7> in <module>()
#       3 # Summarize the data about minutes spent in the classroom
#       4 #total_minutes = list(total_minutes_by_account.values())
# ----> 5 getStatistics(total_minutes_by_account)
#       6 #print('Mean:', np.mean(total_minutes))
#       7 #print('Standard deviation:', str(np.std(total_minutes)))
#
# <ipython-input-19-79e72a4c63a7> in getStatistics(listOfItems)
#       1 def getStatistics (listOfItems):
#       2     import numpy as np
# ----> 3     import mathplotlib.pyplot as plt
#       4     get_ipython().magic('pylab inline')
#       5
#
# ImportError: No module named 'mathplotlib'

# %% [markdown]
# ## Debugging Data Analysis Code

# %%
#####################################
#                 8                 #
#####################################

## Go through a similar process as before to see if there is a problem.
## Locate at least one surprising piece of data, output it, and take a look at it.

#print("Total Minutes ",total_minutes_by_account)
#print("************** Total Minutes items ",total_minutes_by_account.items())

students_max_engament=[];
for student_id,minutes in total_minutes_by_account.items():
    if minutes > 3000:        
        students_max_engament.append(student_id)

print(students_max_engament)

for item in paid_engagement_in_first_week:
    if item["account_key"] in students_max_engament:
        print(item)
# Out:
# ['163']
# {'projects_completed': 0, 'total_minutes_visited': 850.519339666, 'utc_date': datetime.datetime(2015, 7, 9, 0, 0), 'num_courses_visited': 4, 'account_key': '163', 'lessons_completed': 4}
# {'projects_completed': 0, 'total_minutes_visited': 872.633923334, 'utc_date': datetime.datetime(2015, 7, 10, 0, 0), 'num_courses_visited': 6, 'account_key': '163', 'lessons_completed': 6}
# {'projects_completed': 0, 'total_minutes_visited': 777.018903666, 'utc_date': datetime.datetime(2015, 7, 11, 0, 0), 'num_courses_visited': 2, 'account_key': '163', 'lessons_completed': 6}
# {'projects_completed': 0, 'total_minutes_visited': 294.568774, 'utc_date': datetime.datetime(2015, 7, 12, 0, 0), 'num_courses_visited': 1, 'account_key': '163', 'lessons_completed': 2}
# {'projects_completed': 0, 'total_minutes_visited': 471.2139785, 'utc_date': datetime.datetime(2015, 7, 13, 0, 0), 'num_courses_visited': 3, 'account_key': '163', 'lessons_completed': 1}
# ...

# %% [markdown]
# ## Lessons Completed in First Week

# %%
def getTotalsListByAccount(inputList,keyName):
    from collections import defaultdict
    list_by_account= defaultdict(list)
    for item in inputList:
        account_key = item[keyName]
        list_by_account[account_key].append(item)
        #print(item)
    return list_by_account

# %%
def getTotalsDictByAccount(inputDefaultDict,fieldToAdd):
    dict_by_account={}
    for account_key,total in inputDefaultDict.items():
        totals=0
        for item in total:
            totals +=item[fieldToAdd]
        dict_by_account[account_key]=totals        
    return dict_by_account

# %%
#####################################
#                 9                 #
#####################################

## Adapt the code above to find the mean, standard deviation, minimum, and maximum for
## the number of lessons completed by each student during the first week. Try creating
## one or more functions to re-use the code above.

#totalLessonsCompleted=0
#for item in paid_engagement_in_first_week:
#     totalLessonsCompleted+= item['lessons_completed']
    
#print (totalLessonsCompleted)
lessons_by_account = getTotalsListByAccount(paid_engagement_in_first_week,'account_key')
totals_lessons_by_account=getTotalsDictByAccount(lessons_by_account,'lessons_completed')
#print(totals_lessons_by_account)
getStatistics(totals_lessons_by_account)
# Out:
# Mean: 1.63618090452
# Standard deviation: 3.00256129983
# Minimum: 0
# Maximum: 36

# %% [markdown]
# ## Number of Visits in First Week

# %%
######################################
#                 10                 #
######################################

## Find the mean, standard deviation, minimum, and maximum for the number of
## days each student visits the classroom during the first week.
for item in paid_engagement_in_first_week:
    if item['num_courses_visited']>0:
        item['has_visited']=1
    else:
        item['has_visited']=0    

#print(paid_engagement_in_first_week)
# Out:
# [{'projects_completed': 0, 'has_visited': 1, 'total_minutes_visited': 11.6793745, 'utc_date': datetime.datetime(2015, 1, 9, 0, 0), 'num_courses_visited': 1, 'account_key': '0', 'lessons_completed': 0}, {'projects_completed': 0, 'has_visited': 1, 'total_minutes_visited': 37.2848873333, 'utc_date': datetime.datetime(2015, 1, 10, 0, 0), 'num_courses_visited': 2, 'account_key': '0', 'lessons_completed': 0}, {'projects_completed': 0, 'has_visited': 1, 'total_minutes_visited': 53.6337463333, 'utc_date': datetime.datetime(2015, 1, 11, 0, 0), 'num_courses_visited': 2, 'account_key': '0', 'lessons_completed': 0}, {'projects_completed': 0, 'has_visited': 1, 'total_minutes_visited': 33.4892696667, 'utc_date': datetime.datetime(2015, 1, 12, 0, 0), 'num_courses_visited': 1, 'account_key': '0', 'lessons_completed': 0}, {'projects_completed': 0, 'has_visited': 1, 'total_minutes_visited': 64.7796776667, 'utc_date': datetime.datetime(2015, 1, 13, 0, 0), 'num_courses_visited': 1, 'account_key': '0', '
# ...

# %%
has_visited_by_account = getTotalsListByAccount(paid_engagement_in_first_week,'account_key')
totals_has_visited_by_account=getTotalsDictByAccount(has_visited_by_account,'has_visited')
getStatistics(totals_has_visited_by_account)
# Out:
# Mean: 2.86733668342
# Standard deviation: 2.25519800292
# Minimum: 0
# Maximum: 7

# %%
for item in paid_engagement_in_first_week:
    print(item,'\n')
# Out:
# {'projects_completed': 0, 'has_visited': 1, 'total_minutes_visited': 11.6793745, 'utc_date': datetime.datetime(2015, 1, 9, 0, 0), 'num_courses_visited': 1, 'account_key': '0', 'lessons_completed': 0}
#
# {'projects_completed': 0, 'has_visited': 1, 'total_minutes_visited': 37.2848873333, 'utc_date': datetime.datetime(2015, 1, 10, 0, 0), 'num_courses_visited': 2, 'account_key': '0', 'lessons_completed': 0}
#
# {'projects_completed': 0, 'has_visited': 1, 'total_minutes_visited': 53.6337463333, 'utc_date': datetime.datetime(2015, 1, 11, 0, 0), 'num_courses_visited': 2, 'account_key': '0', 'lessons_completed': 0}
#
# {'projects_completed': 0, 'has_visited': 1, 'total_minutes_visited': 33.4892696667, 'utc_date': datetime.datetime(2015, 1, 12, 0, 0), 'num_courses_visited': 1, 'account_key': '0', 'lessons_completed': 0}
#
# ...

# %% [markdown]
# ## Splitting out Passing Students

# %%
for item in project_submissions:
    print(item,'\n')
# Out:
# {'creation_date': datetime.datetime(2015, 1, 14, 0, 0), 'lesson_key': '3176718735', 'processing_state': 'EVALUATED', 'assigned_rating': 'UNGRADED', 'account_key': '256', 'completion_date': datetime.datetime(2015, 1, 16, 0, 0)}
#
# {'creation_date': datetime.datetime(2015, 1, 10, 0, 0), 'lesson_key': '3176718735', 'processing_state': 'EVALUATED', 'assigned_rating': 'INCOMPLETE', 'account_key': '256', 'completion_date': datetime.datetime(2015, 1, 13, 0, 0)}
#
# {'creation_date': datetime.datetime(2015, 1, 20, 0, 0), 'lesson_key': '3176718735', 'processing_state': 'EVALUATED', 'assigned_rating': 'PASSED', 'account_key': '256', 'completion_date': datetime.datetime(2015, 1, 20, 0, 0)}
#
# {'creation_date': datetime.datetime(2015, 3, 10, 0, 0), 'lesson_key': '3176718735', 'processing_state': 'EVALUATED', 'assigned_rating': 'PASSED', 'account_key': '434', 'completion_date': datetime.datetime(2015, 3, 13, 0, 0)}
#
# ...

# %%
######################################
#                 11                 #
######################################

## Create two lists of engagement data for paid students in the first week.
## The first list should contain data for students who eventually pass the
## subway project, and the second list should contain data for students
## who do not.

subway_project_lesson_keys = ['746169184', '3176718735']

passing_engagement =[]
non_passing_engagement =[]

pass_subway_project_keys=set()

for item in non_udacity_submissions:        
        if item["lesson_key"] in subway_project_lesson_keys and (item['assigned_rating']=='PASSED' or item['assigned_rating']=='DISTINCTION') and item['account_key'] in paid_students:
            pass_subway_project_keys.add(item['account_key'])
            
#len(pass_subway_project_keys)        

for engagement in paid_engagement_in_first_week:
    if engagement['account_key'] in pass_subway_project_keys:
        passing_engagement.append(engagement)
    else:
        non_passing_engagement.append(engagement)


print(len(passing_engagement))
print(len(non_passing_engagement))
# Out:
# 4527
# 2392

# %% [markdown]
# ## Comparing the Two Student Groups

# %%
######################################
#                 12                 #
######################################

## Compute some metrics you're interested in and see how they differ for
## students who pass the subway project vs. students who don't. A good
## starting point would be the metrics we looked at earlier (minutes spent
## in the classroom, lessons completed, and days visited).

#days visited
days_visited_passing_by_account = getTotalsListByAccount(passing_engagement,'account_key')
totals_days_visited_passing_by_account=getTotalsDictByAccount(days_visited_passing_by_account,'has_visited')

print('PASSING STUDENTS DAYS VISITED')
getStatistics(totals_days_visited_passing_by_account)
print('')
days_visited_non_passing_by_account = getTotalsListByAccount(non_passing_engagement,'account_key')
totals_days_visited_non_passing_by_account=getTotalsDictByAccount(days_visited_non_passing_by_account,'has_visited')
print('PASSING STUDENTS DAYS VISITED')
getStatistics(totals_days_visited_non_passing_by_account)
print('')

#lesons completed
lessons_completed_passing_by_account = getTotalsListByAccount(passing_engagement,'account_key')
totals_lessons_completed_passing_by_account=getTotalsDictByAccount(lessons_completed_passing_by_account,'lessons_completed')

print('PASSING STUDENTS LESSONS COMPLETED')
getStatistics(totals_lessons_completed_passing_by_account)

print('')

lessons_completed_non_passing_by_account = getTotalsListByAccount(non_passing_engagement,'account_key')
totals_lessons_completed_non_passing_by_account=getTotalsDictByAccount(lessons_completed_non_passing_by_account,'lessons_completed')
print('PASSING STUDENTS LESSONS COMPLETED')
getStatistics(totals_lessons_completed_non_passing_by_account)

print('')

#minutes visited
total_minutes_visited_passing_by_account = getTotalsListByAccount(passing_engagement,'account_key')
totals_total_minutes_visited_passing_by_account=getTotalsDictByAccount(total_minutes_visited_passing_by_account,'total_minutes_visited')

print('PASSING STUDENTS MINUTES VISITED')
getStatistics(totals_total_minutes_visited_passing_by_account)

print('')

total_minutes_visited_non_passing_by_account = getTotalsListByAccount(non_passing_engagement,'account_key')
total_minutes_visited_completed_non_passing_by_account=getTotalsDictByAccount(total_minutes_visited_non_passing_by_account,'total_minutes_visited')
print('PASSING STUDENTS MINUTES VISITED')
getStatistics(total_minutes_visited_completed_non_passing_by_account)
# Out:
# PASSING STUDENTS DAYS VISITED
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-149-82676643c792> in <module>()
#      13
#      14 print('PASSING STUDENTS DAYS VISITED')
# ---> 15 getStatistics(totals_days_visited_passing_by_account)
#      16 print('')
#      17 days_visited_non_passing_by_account = getTotalsListByAccount(non_passing_engagement,'account_key')
#
# <ipython-input-148-fbcc93c217ec> in getStatistics(listOfItems)
#       1 def getStatistics (listOfItems):
#       2     import numpy as np
# ----> 3     import mathplotlib.pyplot as plt
#       4
#       5     new_List = list(listOfItems.values())
#
# ImportError: No module named 'mathplotlib'

# %% [markdown]
# ## Making Histograms

# %%
######################################
#                 13                 #
######################################

## Make histograms of the three metrics we looked at earlier for both
## students who passed the subway project and students who didn't. You
## might also want to make histograms of any other metrics you examined.
print(totals_days_visited_passing_by_account)
# Out:
# {'216': 3, '426': 0, '413': 4, '497': 4, '411': 0, '380': 2, '269': 2, '143': 3, '15': 5, '539': 5, '144': 5, '623': 5, '293': 5, '130': 0, '490': 2, '489': 6, '508': 5, '425': 5, '326': 6, '42': 6, '387': 0, '542': 6, '70': 3, '39': 4, '260': 5, '639': 3, '455': 6, '60': 0, '588': 2, '85': 3, '280': 5, '393': 1, '467': 4, '20': 5, '347': 5, '74': 3, '199': 6, '33': 5, '112': 6, '498': 5, '578': 1, '221': 3, '355': 4, '75': 1, '574': 0, '165': 6, '239': 1, '642': 4, '446': 4, '193': 4, '72': 6, '349': 2, '384': 6, '301': 5, '7': 3, '390': 2, '323': 4, '119': 5, '647': 1, '305': 7, '601': 0, '306': 0, '227': 4, '286': 2, '203': 7, '372': 3, '544': 7, '309': 4, '396': 0, '418': 1, '261': 0, '80': 2, '331': 3, '211': 6, '125': 7, '256': 0, '16': 2, '352': 4, '463': 5, '477': 5, '266': 6, '322': 0, '284': 1, '204': 7, '99': 4, '367': 7, '218': 7, '46': 1, '622': 4, '188': 1, '62': 2, '232': 7, '22': 5, '555': 4, '57': 3, '210': 3, '559': 3, '26': 3, '190': 1, '83': 4, '582': 1, '318': 3,
# ...

# %% [markdown]
# ## Improving Plots and Sharing Findings

# %%
######################################
#                 14                 #
######################################

## Make a more polished version of at least one of your visualizations
## from earlier. Try importing the seaborn library to make the visualization
## look better, adding axis labels and a title, and changing one or more
## arguments to the hist() function.
